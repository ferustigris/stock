# %% [markdown]
# <a href="https://colab.research.google.com/github/ferustigris/stock/blob/master/Update_stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install dependencies
#
# Install dependencies for Yahoo finance and gsheets. As well as client_secret.json required in root directory. Could be downloaded from [here](https://console.cloud.google.com/apis/api/drive.googleapis.com/metrics?project=gold-access-268714)

# %%
# !pip install pygsheets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pygsheets in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: google-api-python-client>=2.50.0 in /usr/local/lib/python3.10/dist-packages (from pygsheets) (2.84.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pygsheets) (1.0.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (0.21.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.7.1->pygsheets) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.20.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.50.0->pygsheets) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.50.0->pygsheets) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.50.0->pygsheets) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.50.0->pygsheets) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client>=2.50.0->pygsheets) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.1->pygsheets) (3.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.50.0->pygsheets) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.4)

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.18)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.7)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (40.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %% [markdown]
# # Framework

# %% [markdown]
# Create Yahoo API reader:

# %%
import yfinance as yf

BLNS = 1000_000_000

class NoValue(Exception):
  pass

class YahooFinanceReader:
    """Yahoo Finance Reader class for access via API"""

    class Ticker:
        """Case-class for the particular ticket"""

        def __init__(self, tkt):
            """Pass ticket object in the constructor"""
            self.tkt = tkt

        def get_current_price(self):
            """Get very current price of the ticket"""
            return self.tkt.info["currentPrice"]

        def get_divs(self):
            """Get annual divs of the ticket"""
            # print(self.tkt.dividends)
            divs = self.tkt.info["trailingAnnualDividendYield"]
            print("divs:")
            print(divs)
            if not divs:
              try:
                divs = self.tkt.info["dividendYield"]
                print("dividendYield:")
                print(divs)
              except KeyError:
                print("dividendYield: key error")
            if not divs:
              try:
                divs = self.tkt.info["forwardAnnualDividendYield"]
                print("forwardAnnualDividendYield:")
                print(divs)
              except KeyError:
                print("forwardAnnualDividendYield: key error")
            return divs

        def get_net(self):
            """Get annual netIncomeToCommon of the ticket in billions"""
            for i in range(3):
              try:
                return self.tkt.info["netIncomeToCommon"] / BLNS
              except KeyError:
                print("ERROR: %s" % "netin key error")
            raise NoValue("ERROR: %s" % "netin key error")

        def get_revenue(self):
            for i in range(3):
              try:
                """Get annual totalRevenue of the ticket in billions"""
                return self.tkt.info["totalRevenue"] / BLNS
              except KeyError:
                print("ERROR: %s" % "Total revenue key error")
            raise NoValue("ERROR: %s" % "Total revenue key error")

        def get_assets(self):
            """Get total assets of the ticket in billions"""
            return self.tkt.info["totalAssets"] / BLNS

        def get_shares(self):
            """Get shares volume of the ticket in billions"""
            return self.tkt.info["sharesOutstanding"] / BLNS

        def get_sma200days(self):
            """Get twoHundredDayAverage of the ticket in billions"""
            return self.tkt.info["twoHundredDayAverage"] / BLNS

        def get_history(self):
          return self.tkt.history(period="max")

    def get_ticker(self, ticker_name):
        """Returns ticket object by ticket name"""
        print("Getting ticket object for %s..." % ticker_name)
        return self.Ticker(yf.Ticker(ticker_name))

# %% [markdown]
# Create gsheet writer, the file [itself](https://docs.google.com/spreadsheets/d/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/edit#gid=1283370971):

# %%
import pygsheets

# authorization
MAX_AMOUNT_ROWS = 50
COL_PRICE = 'E'
COL_DIVS = 'V'
COL_REVENUE = 'L'
COL_NET = 'M'
COL_ASSETS = 'O'
COL_SHARES = 'D'
COL_AVG = 'F'
NYSE_SHEET_NUMBER = 1
EU_SHEET_NUMBER = 3
PATH_TO_KEY_JSON = 'client_secret.json'
GSHEET_NAME = 'Finance stock and invest'


class GSheetUpdater:
    """Class for Finance stock and invest updates"""
    def __init__(self, sheet=NYSE_SHEET_NUMBER):
        self.__gc = pygsheets.authorize(service_file=PATH_TO_KEY_JSON)
        # open the google spreadsheet (by is the name of my sheet)
        self.__sh = self.__gc.open(GSHEET_NAME)

        # select the right sheet
        self.__wks = self.__sh[sheet]

    def apply_for_all(self, func, col_to_be_updated):
        """applies function for all rows"""
        for i in range(2, MAX_AMOUNT_ROWS):
            header = self.__wks.cell('B%i' % i)
            ticket = header.value
            try:
              self.__wks.update_value('%s%i' % (col_to_be_updated, i), try_func(ticket))
            except NoValue:
              print("ERROR: %s" % s)

    def apply_for_all(self, cols_and_funcs, start_from=2):
        """applies function for all rows"""
        for i in range(start_from, MAX_AMOUNT_ROWS):
            header = self.__wks.cell('B%i' % i)
            ticket = header.value
            if not ticket:
              raise NoValue("No ticket found")
            for (col_to_be_updated, func) in cols_and_funcs.items():
                print("Index=%i" % i)
                try:
                  self.__wks.update_value('%s%i' % (col_to_be_updated, i), func(ticket))
                except NoValue:
                    print("ERROR: %s" % s)

# %% [markdown]
# # Update stocks

# %% [markdown]
# What we are going to update:

# %%
r = YahooFinanceReader()


def update_price(ticket):
    """Apply the function for every ticker"""
    print("Update price for %s" % ticket)
    price = r.get_ticker(ticket).get_current_price()
    return price


cols_and_funcs = {
    COL_PRICE: update_price,
    COL_DIVS: lambda ticket: r.get_ticker(ticket).get_divs(),
    COL_REVENUE: lambda ticket: r.get_ticker(ticket).get_revenue(),
    # COL_ASSETS: lambda ticket: r.get_ticker(ticket).get_assets(),
    COL_SHARES: lambda ticket: r.get_ticker(ticket).get_shares(),
    COL_NET: lambda ticket: r.get_ticker(ticket).get_net(),
    COL_AVG: lambda ticket: r.get_ticker(ticket).get_sma200days()
}

# %% [markdown]
# Updating gsheet for EU:

# %%
sheet_eu = GSheetUpdater(EU_SHEET_NUMBER)
sheet_eu.apply_for_all(cols_and_funcs, 2)

# %% [markdown]
# Updating gsheet for NYSE:

# %%
sheet_ny = GSheetUpdater(NYSE_SHEET_NUMBER)
sheet_ny.apply_for_all(cols_and_funcs, 2)
# Out:
# Index=2
# Update price for RIO
# Getting ticket object for RIO...
# Index=2
# Getting ticket object for RIO...
# divs:
# 0.08257282
# Index=2
# Getting ticket object for RIO...
# Index=2
# Getting ticket object for RIO...
# Index=2
# Getting ticket object for RIO...
# Index=2
# Getting ticket object for RIO...
# Index=3
# Update price for HYMTF
# Getting ticket object for HYMTF...
# Index=3
# Getting ticket object for HYMTF...
# divs:
# 172.83951
# Index=3
# Getting ticket object for HYMTF...
# Index=3
# Getting ticket object for HYMTF...
# Index=3
# Getting ticket object for HYMTF...
# Index=3
# Getting ticket object for HYMTF...
# Index=4
# Update price for VZ
# Getting ticket object for VZ...
# Index=4
# Getting ticket object for VZ...
# divs:
# 0.0746123
# Index=4
# Getting ticket object for VZ...
# Index=4
# Getting ticket object for VZ...
# Index=4
# Getting ticket object for VZ...
# Index=4
# Getting ticket object for VZ...
# Index=5
# Update price for OKE
# Getting ticket object for OKE...
# Index=5
# Getting ticket object for OKE...
# divs:
# 0.065659195
# Index=5
# Getting ticket object for OKE...
# Index=5
# Getting ticket object for OKE...
# Index=5
# Getting ticket object for OKE...
# Index=5
# Getting ticket object for OKE...
# Index=6
# Update price for T
# Getting ticket object for T...
# Index=6
# Getting ticket object for T...
# divs:
# 0.07326733
# Index=6
# Getting ticket object for T...
# Index=6
# Getting ticket object for T...
# Index=6
# Getting ticket object for T...
# Index=6
# Getting ticket object for T...
# Index=7
# Update price for DOW
# Getting ticket object for DOW...
# Index=7
# Getting ticket object for DOW...
# divs:
# 0.055588644
# Index=7
# Getting ticket object for DOW...
# Index=7
# Getting ticket object for DOW...
# Index=7
# Getting ticket object for DOW...
# Index=7
# Getting ticket object for DOW...
# Index=8
# Update price for INTC
# Getting ticket object for INTC...
# Index=8
# Getting ticket object for INTC...
# divs:
# 0.05310219
# Index=8
# Getting ticket object for INTC...
# Index=8
# Getting ticket object for INTC...
# Index=8
# Getting ticket object for INTC...
# Index=8
# Getting ticket object for INTC...
# Index=9
# Update price for MMM
# Getting ticket object for MMM...
# Index=9
# Getting ticket object for MMM...
# divs:
# 0.06151468
# Index=9
# Getting ticket object for MMM...
# Index=9
# Getting ticket object for MMM...
# Index=9
# Getting ticket object for MMM...
# Index=9
# Getting ticket object for MMM...
# Index=10
# Update price for IBM
# Getting ticket object for IBM...
# Index=10
# Getting ticket object for IBM...
# divs:
# 0.052066896
# Index=10
# Getting ticket object for IBM...
# Index=10
# Getting ticket object for IBM...
# Index=10
# Getting ticket object for IBM...
# Index=10
# Getting ticket object for IBM...
# Index=11
# Update price for USB
# Getting ticket object for USB...
# Index=11
# Getting ticket object for USB...
# divs:
# 0.062274665
# Index=11
# Getting ticket object for USB...
# Index=11
# Getting ticket object for USB...
# Index=11
# Getting ticket object for USB...
# Index=11
# Getting ticket object for USB...
# Index=12
# Update price for KHC
# Getting ticket object for KHC...
# Index=12
# Getting ticket object for KHC...
# divs:
# 0.041819133
# Index=12
# Getting ticket object for KHC...
# Index=12
# Getting ticket object for KHC...
# Index=12
# Getting ticket object for KHC...
# Index=12
# Getting ticket object for KHC...
# Index=13
# Update price for PFE
# Getting ticket object for PFE...
# Index=13
# Getting ticket object for PFE...
# divs:
# 0.042558815
# Index=13
# Getting ticket object for PFE...
# Index=13
# Getting ticket object for PFE...
# Index=13
# Getting ticket object for PFE...
# Index=13
# Getting ticket object for PFE...
# Index=14
# Update price for CVX
# Getting ticket object for CVX...
# Index=14
# Getting ticket object for CVX...
# divs:
# 0.037331782
# Index=14
# Getting ticket object for CVX...
# Index=14
# Getting ticket object for CVX...
# Index=14
# Getting ticket object for CVX...
# Index=14
# Getting ticket object for CVX...
# Index=15
# Update price for NRG
# Getting ticket object for NRG...
# Index=15
# Getting ticket object for NRG...
# divs:
# 0.04348476
# Index=15
# Getting ticket object for NRG...
# Index=15
# Getting ticket object for NRG...
# Index=15
# Getting ticket object for NRG...
# Index=15
# Getting ticket object for NRG...
# Index=16
# Update price for VLO
# Getting ticket object for VLO...
# Index=16
# Getting ticket object for VLO...
# divs:
# 0.034988515
# Index=16
# Getting ticket object for VLO...
# Index=16
# Getting ticket object for VLO...
# Index=16
# Getting ticket object for VLO...
# Index=16
# Getting ticket object for VLO...
# Index=17
# Update price for TSM
# Getting ticket object for TSM...
# Index=17
# Getting ticket object for TSM...
# divs:
# 0.111441314
# Index=17
# Getting ticket object for TSM...
# Index=17
# Getting ticket object for TSM...
# Index=17
# Getting ticket object for TSM...
# Index=17
# Getting ticket object for TSM...
# Index=18
# Update price for KO
# Getting ticket object for KO...
# Index=18
# Getting ticket object for KO...
# divs:
# 0.02946532
# Index=18
# Getting ticket object for KO...
# Index=18
# Getting ticket object for KO...
# Index=18
# Getting ticket object for KO...
# Index=18
# Getting ticket object for KO...
# Index=19
# Update price for FDX
# Getting ticket object for FDX...
# Index=19
# Getting ticket object for FDX...
# divs:
# 0.020437177
# WARNING:googleapiclient.http:Sleeping 0.38 seconds before retry 1 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V19%3AV19?valueInputOption=USER_ENTERED&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 0.03 seconds before retry 2 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V19%3AV19?valueInputOption=USER_ENTERED&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 1.75 seconds before retry 3 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V19%3AV19?valueInputOption=USER_ENTERED&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 1.54 seconds before retry 1 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V19%3AV19?valueInputOption=USER_ENTERED&alt=json, after 429
# Index=19
# Getting ticket object for FDX...
# Index=19
# Getting ticket object for FDX...
# Index=19
# Getting ticket object for FDX...
# Index=19
# Getting ticket object for FDX...
# Index=20
# Update price for PG
# Getting ticket object for PG...
# Index=20
# Getting ticket object for PG...
# divs:
# 0.025125526
# Index=20
# Getting ticket object for PG...
# Index=20
# Getting ticket object for PG...
# Index=20
# Getting ticket object for PG...
# Index=20
# Getting ticket object for PG...
# Index=21
# Update price for JNJ
# Getting ticket object for JNJ...
# Index=21
# Getting ticket object for JNJ...
# divs:
# 0.029272715
# Index=21
# Getting ticket object for JNJ...
# Index=21
# Getting ticket object for JNJ...
# Index=21
# Getting ticket object for JNJ...
# Index=21
# Getting ticket object for JNJ...
# Index=22
# Update price for BAC
# Getting ticket object for BAC...
# Index=22
# Getting ticket object for BAC...
# divs:
# 0.03088392
# Index=22
# Getting ticket object for BAC...
# Index=22
# Getting ticket object for BAC...
# Index=22
# Getting ticket object for BAC...
# Index=22
# Getting ticket object for BAC...
# Index=23
# Update price for MSFT
# Getting ticket object for MSFT...
# Index=23
# Getting ticket object for MSFT...
# divs:
# 0.008161512
# Index=23
# Getting ticket object for MSFT...
# Index=23
# Getting ticket object for MSFT...
# Index=23
# Getting ticket object for MSFT...
# Index=23
# Getting ticket object for MSFT...
# Index=24
# Update price for GOOGL
# Getting ticket object for GOOGL...
# Index=24
# Getting ticket object for GOOGL...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# Index=24
# Getting ticket object for GOOGL...
# Index=24
# Getting ticket object for GOOGL...
# Index=24
# Getting ticket object for GOOGL...
# Index=24
# Getting ticket object for GOOGL...
# Index=25
# Update price for V
# Getting ticket object for V...
# Index=25
# Getting ticket object for V...
# divs:
# 0.007722267
# Index=25
# Getting ticket object for V...
# Index=25
# Getting ticket object for V...
# Index=25
# Getting ticket object for V...
# Index=25
# Getting ticket object for V...
# Index=26
# Update price for AAPL
# Getting ticket object for AAPL...
# Index=26
# Getting ticket object for AAPL...
# divs:
# 0.0053182263
# Index=26
# Getting ticket object for AAPL...
# Index=26
# Getting ticket object for AAPL...
# Index=26
# Getting ticket object for AAPL...
# Index=26
# Getting ticket object for AAPL...
# Index=27
# Update price for MA
# Getting ticket object for MA...
# Index=27
# Getting ticket object for MA...
# divs:
# 0.00572911
# Index=27
# Getting ticket object for MA...
# Index=27
# Getting ticket object for MA...
# Index=27
# Getting ticket object for MA...
# Index=27
# Getting ticket object for MA...
# Index=28
# Update price for AAL
# Getting ticket object for AAL...
# Index=28
# Getting ticket object for AAL...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# Index=28
# Getting ticket object for AAL...
# Index=28
# Getting ticket object for AAL...
# Index=28
# Getting ticket object for AAL...
# Index=28
# Getting ticket object for AAL...
# Index=29
# Update price for BABA
# Getting ticket object for BABA...
# Index=29
# Getting ticket object for BABA...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# Index=29
# Getting ticket object for BABA...
# Index=29
# Getting ticket object for BABA...
# Index=29
# Getting ticket object for BABA...
# Index=29
# Getting ticket object for BABA...
# Index=30
# Update price for BIDU
# Getting ticket object for BIDU...
# Index=30
# Getting ticket object for BIDU...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# WARNING:googleapiclient.http:Sleeping 1.59 seconds before retry 1 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V30%3AV30?valueInputOption=USER_ENTERED&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 1.17 seconds before retry 2 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V30%3AV30?valueInputOption=USER_ENTERED&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 4.30 seconds before retry 3 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V30%3AV30?valueInputOption=USER_ENTERED&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 1.33 seconds before retry 1 of 3 for request: PUT https://sheets.googleapis.com/v4/spreadsheets/1hc8kcZJDUJ91qL-mp_NDxZUkrOnhihdzNhxVKRF04fQ/values/%27NYSE%27%21V30%3AV30?valueInputOption=USER_ENTERED&alt=json, after 429
# Index=30
# Getting ticket object for BIDU...
# Index=30
# Getting ticket object for BIDU...
# Index=30
# Getting ticket object for BIDU...
# Index=30
# Getting ticket object for BIDU...
# Index=31
# Update price for JD
# Getting ticket object for JD...
# Index=31
# Getting ticket object for JD...
# divs:
# 0.0
# dividendYield:
# 0.0187
# Index=31
# Getting ticket object for JD...
# Index=31
# Getting ticket object for JD...
# Index=31
# Getting ticket object for JD...
# Index=31
# Getting ticket object for JD...
# Index=32
# Update price for META
# Getting ticket object for META...
# Index=32
# Getting ticket object for META...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# Index=32
# Getting ticket object for META...
# Index=32
# Getting ticket object for META...
# Index=32
# Getting ticket object for META...
# Index=32
# Getting ticket object for META...
# Index=33
# Update price for PYPL
# Getting ticket object for PYPL...
# Index=33
# Getting ticket object for PYPL...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# Index=33
# Getting ticket object for PYPL...
# Index=33
# Getting ticket object for PYPL...
# Index=33
# Getting ticket object for PYPL...
# Index=33
# Getting ticket object for PYPL...
# Index=34
# Update price for PARA
# Getting ticket object for PARA...
# Index=34
# Getting ticket object for PARA...
# divs:
# 0.06818182
# Index=34
# Getting ticket object for PARA...
# Index=34
# Getting ticket object for PARA...
# Index=34
# Getting ticket object for PARA...
# Index=34
# Getting ticket object for PARA...
# Index=35
# Update price for DVN
# Getting ticket object for DVN...
# Index=35
# Getting ticket object for DVN...
# divs:
# 0.105702944
# Index=35
# Getting ticket object for DVN...
# Index=35
# Getting ticket object for DVN...
# Index=35
# Getting ticket object for DVN...
# Index=35
# Getting ticket object for DVN...
# Index=36
# Update price for PXD
# Getting ticket object for PXD...
# Index=36
# Getting ticket object for PXD...
# divs:
# 0.13121387
# Index=36
# Getting ticket object for PXD...
# Index=36
# Getting ticket object for PXD...
# Index=36
# Getting ticket object for PXD...
# Index=36
# Getting ticket object for PXD...
# Index=37
# Update price for SEDG
# Getting ticket object for SEDG...
# Index=37
# Getting ticket object for SEDG...
# divs:
# 0.0
# dividendYield: key error
# forwardAnnualDividendYield: key error
# Index=37
# Getting ticket object for SEDG...
# Index=37
# Getting ticket object for SEDG...
# Index=37
# Getting ticket object for SEDG...
# Index=37
# Getting ticket object for SEDG...
# Index=38
# Update price for PBR-A
# Getting ticket object for PBR-A...
# Index=38
# Getting ticket object for PBR-A...
# divs:
# 1.0614653
# Index=38
# Getting ticket object for PBR-A...
# Index=38
# Getting ticket object for PBR-A...
# Index=38
# Getting ticket object for PBR-A...
# Index=38
# Getting ticket object for PBR-A...
# Index=39
# Update price for C
# Getting ticket object for C...
# Index=39
# Getting ticket object for C...
# divs:
# 0.04612254
# Index=39
# Getting ticket object for C...
# Index=39
# Getting ticket object for C...
# Index=39
# Getting ticket object for C...
# Index=39
# Getting ticket object for C...
# Index=40
# Update price for OXY
# Getting ticket object for OXY...
# Index=40
# Getting ticket object for OXY...
# divs:
# 0.009692228
# Index=40
# Getting ticket object for OXY...
# Index=40
# Getting ticket object for OXY...
# Index=40
# Getting ticket object for OXY...
# Index=40
# Getting ticket object for OXY...
# ---------------------------------------------------------------------------
# NoValue                                   Traceback (most recent call last)
# <ipython-input-35-7f488e60bb7c> in <cell line: 2>()
#       1 sheet_ny = GSheetUpdater(NYSE_SHEET_NUMBER)
# ----> 2 sheet_ny.apply_for_all(cols_and_funcs, 2)
#
# <ipython-input-28-fbbd3162ebdb> in apply_for_all(self, cols_and_funcs, start_from)
#      42             ticket = header.value
#      43             if not ticket:
# ---> 44               raise NoValue("No ticket found")
#      45             for (col_to_be_updated, func) in cols_and_funcs.items():
#      46                 print("Index=%i" % i)
#
# NoValue: No ticket found

# %%
from google.colab import drive
drive.mount('/content/drive')
